# %%
import numpy as np
import pandas as pd

from statsmodels.formula.api import ols
import statsmodels.api as sm

from sklearn import svm
from sklearn.datasets import samples_generator
from sklearn.feature_selection import SelectKBest, f_regression
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report

from matplotlib import pyplot as plt
from sklearn import datasets, linear_model
from sklearn import metrics

from sklearn import preprocessing
from sklearn import pipeline

print(__doc__)
# Out:
# Automatically created module for IPython interactive environment

# %%
df2 = pd.read_csv('ted_main_copy.csv')
df2.columns
# Out:
# Index(['comments', 'description', 'duration', 'event', 'film_date',
#        'languages', 'main_speaker', 'name', 'num_speaker', 'published_date',
#        'ratings', 'related_talks', 'speaker_occupation', 'tags', 'title',
#        'url', 'views'],
#       dtype='object')

# %%
features = df.iloc[:,:-1]
target = df.views_log
index = df.iloc[:,0]

# %%
df.columns
df.drop
# Out:
# Index(['Unnamed: 0', 'Talk_ID', 'Funny', 'Beautiful', 'Ingenious',
#        'Courageous', 'Longwinded', 'Confusing', 'Informative', 'Fascinating',
#        'Unconvincing', 'Persuasive', 'Jaw_dropping', 'OK', 'Obnoxious',
#        'Inspiring', 'total', 'log_views', 'Other_TED', 'TED', 'TEDGlobal',
#        'TEDMED', 'TEDSalon', 'TEDWomen', 'TEDx', 'views_log'],
#       dtype='object')

# %%
X_train, X_test, y_train, y_test = train_test_split(features, target, random_state=42,test_size=0.2)

# %%
new = pd.read_csv('ted_main_copy.csv')
df['duration'] = new['duration']
df.log_duration = np.log(df['duration'])
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
df.head()
# Out:
#    Unnamed: 0  Talk_ID      Funny  Beautiful  Ingenious  Courageous  \
# 0           0        1  20.932116   4.872617   6.470895    3.466132
# 1           1        2  18.515997   1.974132   1.906059    4.731110
# 2           2        3  34.099752   2.122391   6.473293    1.591793
# 3           3        4   1.580922   7.797428   2.813505   20.364416
# 4           4        5   5.424390   3.676098  12.495610    1.240976
#
#    Longwinded  Confusing  Informative  Fascinating    ...     Other_TED  TED  \
# 0    0.412356   0.257856     7.827301    11.274254    ...             0    1
# 1    3.846154   2.110279    15.078285     4.492852    ...             0    1
# 2    2.759109   0.955076    13.972409     5.871949    ...             0    1
# 3    1.420150   0.857449    10.182208     3.536977    ...             0    1
# 4    0.429268   0.280976    21.201951    17.974634    ...             0    1
#
#    TEDGlobal  TEDMED  TEDSalon  TEDWomen  TEDx  views_log  months_ago  \
# ...

# %%
x = pd.read_csv('cleaned_data')
x['months_ago']
df['months_ago'] = x['months_ago']

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression

y = df.views_log
X = df.iloc[:,:-1]

poly = PolynomialFeatures(3)
X_fin = poly.fit_transform(X)

reg_poly = LinearRegression().fit(X_fin, y)
predict_X = reg_poly.predict(X_fin)

# %%
import statsmodels.api as sm
from statsmodels.formula.api import ols

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Talk_ID', 'Funny', 'Beautiful', 'Ingenious',
#        'Courageous', 'Longwinded', 'Confusing', 'Informative', 'Fascinating',
#        'Unconvincing', 'Persuasive', 'Jaw_dropping', 'OK', 'Obnoxious',
#        'Inspiring', 'total', 'log_views', 'Other_TED', 'TED', 'TEDGlobal',
#        'TEDMED', 'TEDSalon', 'TEDWomen', 'TEDx', 'views_log', 'months_ago'],
#       dtype='object')

# %%
df['minus_months'] = df.months_ago.apply(lambda x: x*(-1))

# %%
df['funny_sq'] = df.Funny.apply(lambda x: x**2)

# %%
df.drop(columns='minutes2')
# Out:
#       Unnamed: 0  Talk_ID      Funny  Beautiful  Ingenious  Courageous  \
# 0              0        1  20.932116   4.872617   6.470895    3.466132
# 1              1        2  18.515997   1.974132   1.906059    4.731110
# 2              2        3  34.099752   2.122391   6.473293    1.591793
# 3              3        4   1.580922   7.797428   2.813505   20.364416
# 4              4        5   5.424390   3.676098  12.495610    1.240976
# 5              5        6   7.173545   4.595756   2.584299    4.693399
# 6              6        7  41.365529   4.612823   5.328893    7.943381
# 7              7        8   0.872093   9.496124  18.895349    3.294574
# 8              8        9   1.517067   3.666245   5.335019   14.209861
# 9              9       10   0.311863   9.199952   1.391388    5.709488
# 10            10       11   1.005025   2.847571  14.405360    9.436069
# 11            11       12   0.827815  11.589404   3.311258   15.894040
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Talk_ID', 'Funny', 'Beautiful', 'Ingenious',
#        'Courageous', 'Longwinded', 'Confusing', 'Informative', 'Fascinating',
#        'Unconvincing', 'Persuasive', 'Jaw_dropping', 'OK', 'Obnoxious',
#        'Inspiring', 'total', 'log_views', 'Other_TED', 'TED', 'TEDGlobal',
#        'TEDMED', 'TEDSalon', 'TEDWomen', 'TEDx', 'views_log', 'months_ago',
#        'duration', 'log_duration', 'minutes', 'minutes2', 'minus_months',
#        'funny_sq'],
#       dtype='object')

# %%
df = df.drop(columns='funny_sq')

# %%
df = df.drop(columns='minutes2')

# %%
df = df.drop(columns='duration')

# %%
# Out:
# Index(['Unnamed: 0', 'Talk_ID', 'Funny', 'Beautiful', 'Ingenious',
#        'Courageous', 'Longwinded', 'Confusing', 'Informative', 'Fascinating',
#        'Unconvincing', 'Persuasive', 'Jaw_dropping', 'OK', 'Obnoxious',
#        'Inspiring', 'total', 'log_views', 'Other_TED', 'TED', 'TEDGlobal',
#        'TEDMED', 'TEDSalon', 'TEDWomen', 'TEDx', 'views_log', 'months_ago',
#        'log_duration', 'minutes', 'minus_months'],
#       dtype='object')

# %%
outcome = 'log_views'
predictors = df.drop(['Talk_ID', 'total', 'Confusing', 'Beautiful', 'log_views', 'views_log', 'Ingenious', 'log_duration'], axis=1)
pred_sum = "+".join(predictors.columns)
formula = outcome + "~" + pred_sum

# %%
model = ols(formula= formula, data= df).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:              log_views   R-squared:                       0.700
# Model:                            OLS   Adj. R-squared:                  0.698
# Method:                 Least Squares   F-statistic:                     310.9
# Date:                Thu, 06 Dec 2018   Prob (F-statistic):               0.00
# Time:                        14:51:59   Log-Likelihood:                -794.69
# No. Observations:                2550   AIC:                             1629.
# Df Residuals:                    2530   BIC:                             1746.
# Df Model:                          19
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Talk_ID', 'Funny', 'Beautiful', 'Ingenious',
#        'Courageous', 'Longwinded', 'Confusing', 'Informative', 'Fascinating',
#        'Unconvincing', 'Persuasive', 'Jaw_dropping', 'OK', 'Obnoxious',
#        'Inspiring', 'total', 'log_views', 'Other_TED', 'TED', 'TEDGlobal',
#        'TEDMED', 'TEDSalon', 'TEDWomen', 'TEDx', 'views_log', 'months_ago',
#        'log_duration', 'minutes', 'minus_months'],
#       dtype='object')

# %%
df.log_views = df.views_log

# %%
df['duration'] = df2['duration']

# %%
df = df.drop(columns='log_duration')

# %%
data = df

# %%
df.head()
# Out:
#    Unnamed: 0  Talk_ID      Funny  Beautiful  Ingenious  Courageous  \
# 0           0        1  20.932116   4.872617   6.470895    3.466132
# 1           1        2  18.515997   1.974132   1.906059    4.731110
# 2           2        3  34.099752   2.122391   6.473293    1.591793
# 3           3        4   1.580922   7.797428   2.813505   20.364416
# 4           4        5   5.424390   3.676098  12.495610    1.240976
#
#    Longwinded  Confusing  Informative  Fascinating    ...     TEDGlobal  \
# 0    0.412356   0.257856     7.827301    11.274254    ...             0
# 1    3.846154   2.110279    15.078285     4.492852    ...             0
# 2    2.759109   0.955076    13.972409     5.871949    ...             0
# 3    1.420150   0.857449    10.182208     3.536977    ...             0
# 4    0.429268   0.280976    21.201951    17.974634    ...             0
#
#    TEDMED  TEDSalon  TEDWomen  TEDx  views_log  months_ago    minutes  \
# ...

# %%
df = df.drop(columns='views_log')

# %%
df.head()
# Out:
#    Unnamed: 0  Talk_ID      Funny  Beautiful  Ingenious  Courageous  \
# 0           0        1  20.932116   4.872617   6.470895    3.466132
# 1           1        2  18.515997   1.974132   1.906059    4.731110
# 2           2        3  34.099752   2.122391   6.473293    1.591793
# 3           3        4   1.580922   7.797428   2.813505   20.364416
# 4           4        5   5.424390   3.676098  12.495610    1.240976
#
#    Longwinded  Confusing  Informative  Fascinating     ...      TEDGlobal  \
# 0    0.412356   0.257856     7.827301    11.274254     ...              0
# 1    3.846154   2.110279    15.078285     4.492852     ...              0
# 2    2.759109   0.955076    13.972409     5.871949     ...              0
# 3    1.420150   0.857449    10.182208     3.536977     ...              0
# 4    0.429268   0.280976    21.201951    17.974634     ...              0
#
#    TEDMED  TEDSalon  TEDWomen  TEDx  months_ago    minutes  minus_months  \
# ...

# %%
from matplotlib import pyplot as plt
from sklearn import datasets, linear_model
from sklearn.model_selection import train_test_split
from sklearn import metrics

# %%
df['views_log'] = df['log_views2']

# %%
df = df.drop(columns='log_views2')

# %%
data = df

# %%
df = df.drop(columns='months_ago')

# %%
df.head()
# Out:
#    Unnamed: 0  Talk_ID      Funny  Beautiful  Ingenious  Courageous  \
# 0           0        1  20.932116   4.872617   6.470895    3.466132
# 1           1        2  18.515997   1.974132   1.906059    4.731110
# 2           2        3  34.099752   2.122391   6.473293    1.591793
# 3           3        4   1.580922   7.797428   2.813505   20.364416
# 4           4        5   5.424390   3.676098  12.495610    1.240976
#
#    Longwinded  Confusing  Informative  Fascinating    ...      TED  TEDGlobal  \
# 0    0.412356   0.257856     7.827301    11.274254    ...        1          0
# 1    3.846154   2.110279    15.078285     4.492852    ...        1          0
# 2    2.759109   0.955076    13.972409     5.871949    ...        1          0
# 3    1.420150   0.857449    10.182208     3.536977    ...        1          0
# 4    0.429268   0.280976    21.201951    17.974634    ...        1          0
#
#    TEDMED  TEDSalon  TEDWomen  TEDx    minutes  minus_months  duration  \
# ...

# %%
df['ted_33'] = df.TED.apply(lambda x: x**3)

# %%
df['ted_global_33'] = df.TEDGlobal.apply(lambda x: x**3)

# %%
df['ted_x_33'] = df.TEDx.apply(lambda x: x**3)

# %%
outcome = 'views_log'
predictors = df.drop(['Talk_ID', 'total', 'Beautiful', 'views_log', 'Ingenious'], axis=1)
pred_sum = "+".join(predictors.columns)
formula = outcome + "~" + pred_sum

# %%
model = ols(formula= formula, data= df).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:              views_log   R-squared:                       0.700
# Model:                            OLS   Adj. R-squared:                  0.698
# Method:                 Least Squares   F-statistic:                     295.3
# Date:                Thu, 06 Dec 2018   Prob (F-statistic):               0.00
# Time:                        15:31:34   Log-Likelihood:                -794.36
# No. Observations:                2550   AIC:                             1631.
# Df Residuals:                    2529   BIC:                             1753.
# Df Model:                          20
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# ...

# %%
df = df.drop(columns='ted_33')

# %%
df = df.drop(columns='ted_global_33')

# %%
df = df.drop(columns='ted_x_33')

# %%
finaldata = df

# %%
df.head()
# Out:
#    Unnamed: 0  Talk_ID      Funny  Beautiful  Ingenious  Courageous  \
# 0           0        1  20.932116   4.872617   6.470895    3.466132
# 1           1        2  18.515997   1.974132   1.906059    4.731110
# 2           2        3  34.099752   2.122391   6.473293    1.591793
# 3           3        4   1.580922   7.797428   2.813505   20.364416
# 4           4        5   5.424390   3.676098  12.495610    1.240976
#
#    Longwinded  Confusing  Informative  Fascinating    ...      TED  TEDGlobal  \
# 0    0.412356   0.257856     7.827301    11.274254    ...        1          0
# 1    3.846154   2.110279    15.078285     4.492852    ...        1          0
# 2    2.759109   0.955076    13.972409     5.871949    ...        1          0
# 3    1.420150   0.857449    10.182208     3.536977    ...        1          0
# 4    0.429268   0.280976    21.201951    17.974634    ...        1          0
#
#    TEDMED  TEDSalon  TEDWomen  TEDx    minutes  minus_months  duration  \
# ...

# %%
df = df.drop(columns='Unnamed: 0')

# %%
df.head()
# Out:
#        Funny  Beautiful  Ingenious  Courageous  Longwinded  Confusing  \
# 0  20.932116   4.872617   6.470895    3.466132    0.412356   0.257856
# 1  18.515997   1.974132   1.906059    4.731110    3.846154   2.110279
# 2  34.099752   2.122391   6.473293    1.591793    2.759109   0.955076
# 3   1.580922   7.797428   2.813505   20.364416    1.420150   0.857449
# 4   5.424390   3.676098  12.495610    1.240976    0.429268   0.280976
#
#    Informative  Fascinating  Unconvincing  Persuasive    ...      TED  \
# 0     7.827301    11.274254      0.319656   11.405313    ...        1
# 1    15.078285     4.492852      8.781484    9.121852    ...        1
# 2    13.972409     5.871949      3.678811    8.135833    ...        1
# 3    10.182208     3.536977      0.964630   12.325831    ...        1
# 4    21.201951    17.974634      0.261463    9.920000    ...        1
#
#    TEDGlobal  TEDMED  TEDSalon  TEDWomen  TEDx    minutes  minus_months  \
# ...

# %%
for i in df.columns[0:11].tolist():
    df[i + '_tedx'] = df[i] * df['TEDx']

# %%
df[df.TEDx ==1].head()
# Out:
#         Funny  Beautiful  Ingenious  Courageous  Longwinded  Confusing  \
# 470  1.756641   4.755784   2.870608    2.656384    1.842331   0.814053
# 474  0.462161  15.540150   5.199307    1.444252    0.577701   1.906412
# 529  1.786942   1.030928   3.951890    1.649485    2.027491   1.305842
# 538  0.448430   0.512492   1.857783    1.281230    2.562460   1.153107
# 539  0.408441   2.450647  12.661675    0.204221    0.544588   0.204221
#
#      Informative  Fascinating  Unconvincing  Persuasive        ...          \
# 470    13.496144    18.080548      1.456727    5.784062        ...
# 474     0.231080    11.785095      2.310803    0.231080        ...
# 529    13.608247    11.443299      4.398625   11.718213        ...
# 538    18.321589     6.278027      6.021781    8.712364        ...
# 539     9.462219    15.384615      1.974132    0.884956        ...
#
#      Beautiful_tedx  Ingenious_tedx  Courageous_tedx  Longwinded_tedx  \
# ...

# %%
features = df.iloc[:,:-1]
target = df.views_log

# %%
X_train, X_test, y_train, y_test = train_test_split(features, target, random_state=23,test_size=0.2)

# %%
features.head(5)
# Out:
#        Funny  Beautiful  Ingenious  Courageous  Longwinded  Confusing  \
# 0  20.932116   4.872617   6.470895    3.466132    0.412356   0.257856
# 1  18.515997   1.974132   1.906059    4.731110    3.846154   2.110279
# 2  34.099752   2.122391   6.473293    1.591793    2.759109   0.955076
# 3   1.580922   7.797428   2.813505   20.364416    1.420150   0.857449
# 4   5.424390   3.676098  12.495610    1.240976    0.429268   0.280976
#
#    Informative  Fascinating  Unconvincing  Persuasive    ...     Other_TED  \
# 0     7.827301    11.274254      0.319656   11.405313    ...             0
# 1    15.078285     4.492852      8.781484    9.121852    ...             0
# 2    13.972409     5.871949      3.678811    8.135833    ...             0
# 3    10.182208     3.536977      0.964630   12.325831    ...             0
# 4    21.201951    17.974634      0.261463    9.920000    ...             0
#
#    TED  TEDGlobal  TEDMED  TEDSalon  TEDWomen  TEDx    minutes  minus_months  \
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(features, target, random_state=1,test_size=0.2)
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (2040, 25) (2040,)
# (510, 25) (510,)

# %%
#fit a model
lm = linear_model.LinearRegression()
model = lm.fit(X_train, y_train)
y_pred = lm.predict(X_test)

# %%
plt.scatter(y_test, y_pred)
plt.xlabel("True Values")
plt.ylabel("Predictions")
# Out:
# Text(0,0.5,'Predictions')

# %%
print ("Score:", model.score(X_test, y_test))
# Out:
# Score: 0.8428470625640061

# %%
print(metrics.mean_absolute_error(y_test, y_pred))
print(metrics.mean_squared_error(y_test, y_pred))
print(np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# 0.17139969599380347
# 0.056419962988649985
# 0.23752886769538137

# %%
target.mean()
# Out:
# 7.999365338912133

# %%
from sklearn.linear_model import LinearRegression
reg = LinearRegression().fit(df[["minutes"]], y)

# %%
plt.scatter(df["minutes"], y, color = "green")
plt.plot(df["minutes"], reg.predict(df[["minutes"]]))
plt.xlabel("minutes")
plt.ylabel("views_log");

# %%
df.to_csv('final_dataframe.csv')

# %%
from sklearn.feature_selection import RFE

# %%
from sklearn.feature_selection import RFE

rfe = RFE(lm, n_features_to_select=24)
rfe.fit(X_train,y_train)

def ranking(ranks, names, order=1):

    ranks = map(lambda x: round(x,2), ranks)
    return list(sorted(zip(ranks, names),reverse=True))

rankings = ranking(np.abs(lm.coef_), X_train.columns)

rankings

# %%
rfe = RFE(lm, n_features_to_select=24)
rfe.fit(X_train,y_train)
# Out:
# RFE(estimator=LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False),
#   n_features_to_select=24, step=1, verbose=0)

# %%
def ranking(ranks, names, order=1):

    ranks = map(lambda x: round(x,2), ranks)
    return list(sorted(zip(ranks, names),reverse=True))

# %%
rankings = ranking(np.abs(lm.coef_), X_train.columns)

# %%
rankings
# Out:
# [(0.04, 'TED'),
#  (0.03, 'Unconvincing'),
#  (0.03, 'TEDGlobal'),
#  (0.03, 'Persuasive'),
#  (0.03, 'Other_TED'),
#  (0.03, 'Jaw_dropping'),
#  (0.03, 'Fascinating'),
#  (0.02, 'TEDSalon'),
#  (0.02, 'TEDMED'),
#  (0.02, 'Inspiring'),
#  (0.02, 'Funny'),
#  (0.01, 'minus_months'),
#  (0.01, 'TEDx'),
#  (0.01, 'TEDWomen'),
#  (0.01, 'OK'),
#  (0.01, 'Longwinded'),
#  (0.01, 'Ingenious'),
#  (0.01, 'Informative'),
#  (0.01, 'Courageous'),
#  (0.01, 'Beautiful'),
#  (0.0, 'total'),
#  (0.0, 'minutes'),
#  (0.0, 'duration'),
#  (0.0, 'Obnoxious'),
#  (0.0, 'Confusing')]

# %%
df.columns
# Out:
# Index(['Funny', 'Beautiful', 'Ingenious', 'Courageous', 'Longwinded',
#        'Confusing', 'Informative', 'Fascinating', 'Unconvincing', 'Persuasive',
#        'Jaw_dropping', 'OK', 'Obnoxious', 'Inspiring', 'total', 'Other_TED',
#        'TED', 'TEDGlobal', 'TEDMED', 'TEDSalon', 'TEDWomen', 'TEDx', 'minutes',
#        'minus_months', 'duration', 'views_log'],
#       dtype='object')

# %%
df = df.drop(columns='duration')

# %%
df = df.drop(columns='total')

# %%
df.head()
# Out:
#        Funny  Beautiful  Ingenious  Courageous  Longwinded  Confusing  \
# 0  20.932116   4.872617   6.470895    3.466132    0.412356   0.257856
# 1  18.515997   1.974132   1.906059    4.731110    3.846154   2.110279
# 2  34.099752   2.122391   6.473293    1.591793    2.759109   0.955076
# 3   1.580922   7.797428   2.813505   20.364416    1.420150   0.857449
# 4   5.424390   3.676098  12.495610    1.240976    0.429268   0.280976
#
#    Informative  Fascinating  Unconvincing  Persuasive    ...      Other_TED  \
# 0     7.827301    11.274254      0.319656   11.405313    ...              0
# 1    15.078285     4.492852      8.781484    9.121852    ...              0
# 2    13.972409     5.871949      3.678811    8.135833    ...              0
# 3    10.182208     3.536977      0.964630   12.325831    ...              0
# 4    21.201951    17.974634      0.261463    9.920000    ...              0
#
#    TED  TEDGlobal  TEDMED  TEDSalon  TEDWomen  TEDx    minutes  minus_months  \
# ...

# %%
finaldata = df

# %%
outcome = 'views_log'
predictors = df.drop(['Beautiful', 'views_log', 'Ingenious'], axis=1)
pred_sum = "+".join(predictors.columns)
formula = outcome + "~" + pred_sum

# %%
model = ols(formula= formula, data= df).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:              views_log   R-squared:                       0.700
# Model:                            OLS   Adj. R-squared:                  0.698
# Method:                 Least Squares   F-statistic:                     295.3
# Date:                Thu, 06 Dec 2018   Prob (F-statistic):               0.00
# Time:                        16:38:21   Log-Likelihood:                -794.36
# No. Observations:                2550   AIC:                             1631.
# Df Residuals:                    2529   BIC:                             1753.
# Df Model:                          20
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %%
x = pd.read_csv('cleaned_data')

# %%
x.columns
# Out:
# Index(['Unnamed: 0', 'description', 'duration', 'months_ago', 'ted_types',
#        'top_rating', 'total_views'],
#       dtype='object')

# %%
df['top_rating'] = x.top_rating

# %%
df.columns
# Out:
# Index(['Funny', 'Beautiful', 'Ingenious', 'Courageous', 'Longwinded',
#        'Confusing', 'Informative', 'Fascinating', 'Unconvincing', 'Persuasive',
#        'Jaw_dropping', 'OK', 'Obnoxious', 'Inspiring', 'Other_TED', 'TED',
#        'TEDGlobal', 'TEDMED', 'TEDSalon', 'TEDWomen', 'TEDx', 'minutes',
#        'minus_months', 'views_log', 'Funny_tedx', 'Beautiful_tedx',
#        'Ingenious_tedx', 'Courageous_tedx', 'Longwinded_tedx',
#        'Confusing_tedx', 'Informative_tedx', 'Fascinating_tedx',
#        'Unconvincing_tedx', 'Persuasive_tedx', 'Jaw_dropping_tedx',
#        'top_rating'],
#       dtype='object')

# %%
graph = x[['top_rating', 'ted_types']]

# %%
graph['views'] = x['total_views']
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
graph = graph.drop(columns='views')

# %%
listy2 = graph.groupby(['top_rating','ted_types'])['top_rating'].count()

# %%
# Out:
# ted_types     Other TED    TED  TEDGlobal  TEDMED  TEDSalon  TEDWomen   TEDx
# top_rating
# Beautiful          22.0   74.0       25.0     2.0       6.0       6.0   18.0
# Confusing           NaN    2.0        NaN     NaN       NaN       NaN    NaN
# Courageous         12.0   20.0       16.0     4.0       3.0       5.0   25.0
# Fascinating        36.0  118.0       51.0     5.0      11.0       2.0   40.0
# Funny              26.0   79.0       18.0     3.0       8.0       7.0   22.0
# Informative       103.0  233.0      146.0    24.0      46.0      16.0  157.0
# Ingenious           7.0   40.0       25.0     2.0       2.0       1.0   26.0
# Inspiring         138.0  321.0      147.0    25.0      31.0      58.0  158.0
# Jaw-dropping        4.0   36.0       10.0     NaN       NaN       NaN    3.0
# Longwinded          1.0    7.0        NaN     NaN       NaN       NaN    NaN
# OK                  2.0    4.0        1.0     NaN       NaN       NaN    NaN
# ...

# %%
listy
# Out:
# top_rating
# Beautiful       153
# Confusing         2
# Courageous       85
# Fascinating     263
# Funny           163
# Informative     725
# Ingenious       103
# Inspiring       878
# Jaw-dropping     53
# Longwinded        8
# OK                7
# Obnoxious         4
# Persuasive       83
# Unconvincing     23
# Name: ted_types, dtype: int64

# %%
listy2.unstack()
# Out:
# ted_types     Other TED    TED  TEDGlobal  TEDMED  TEDSalon  TEDWomen   TEDx
# top_rating
# Beautiful          22.0   74.0       25.0     2.0       6.0       6.0   18.0
# Confusing           NaN    2.0        NaN     NaN       NaN       NaN    NaN
# Courageous         12.0   20.0       16.0     4.0       3.0       5.0   25.0
# Fascinating        36.0  118.0       51.0     5.0      11.0       2.0   40.0
# Funny              26.0   79.0       18.0     3.0       8.0       7.0   22.0
# Informative       103.0  233.0      146.0    24.0      46.0      16.0  157.0
# Ingenious           7.0   40.0       25.0     2.0       2.0       1.0   26.0
# Inspiring         138.0  321.0      147.0    25.0      31.0      58.0  158.0
# Jaw-dropping        4.0   36.0       10.0     NaN       NaN       NaN    3.0
# Longwinded          1.0    7.0        NaN     NaN       NaN       NaN    NaN
# OK                  2.0    4.0        1.0     NaN       NaN       NaN    NaN
# ...

# %%
x_list = ['Inspiring', 'Informative', 'Facsinating', 'Funny', 'Beautiful', 'Ingenious', 'Courageous', 'Persuasive', 'Jaw Dropping', 'Unconvincing', 'Long-winded', 'OK', 'Obnoxious', 'Confusing']
y_list = [878,725,263,163,153,103,85,83,53,23,8,7,4,2]
N = 14
TED = (321, 233, 118)
TEDx = (158, 157, 40,)
TEDGlobal = (147, 146, 51)
OtherTED = (138, 103,36 )
TEDWomen = (58,16,)
TEDSalon = (31,46, )
TEDMED = (25,24 )

ind = np.arange(N)    # the x locations for the groups
width = 0.55       # the width of the bars: can also be len(x) sequence

p1 = plt.bar(ind, 'TED', width, color='#d62728')
p2 = plt.bar(ind, 'TEDx', width, bottom='TED')
p3 = plt.bar(ind, 'TEDGlobal', width)
p4 = plt.bar(ind, 'OtherTED', width)
p5 = plt.bar(ind, 'TEDWomen', width)
p6 = plt.bar(ind, 'TEDSalon', width)
p7 = plt.bar(ind, 'TEDMED', width)

plt.ylabel('Number of Ted Talks')
plt.title('Views and Attributes by Ted Talk Type')
#plt.figure(figsize=(20,30))
plt.xticks(ind, x_list, rotation='vertical')
plt.yticks(np.arange(0, 1000 , 100))

#plt.legend((p1[0], p2[0]), ('Men', 'Women'))

plt.show()

# %%
ted_types	Other TED	TED	TEDGlobal	TEDMED	TEDSalon	TEDWomen	TEDx
top_rating							
Beautiful	22.0	74.0	25.0	2.0	6.0	6.0	18.0
Confusing	NaN	2.0	NaN	NaN	NaN	NaN	NaN
Courageous	12.0	20.0	16.0	4.0	3.0	5.0	25.0
Fascinating	36.0	118.0	51.0	5.0	11.0	2.0	40.0
Funny	26.0	79.0	18.0	3.0	8.0	7.0	22.0
Informative	103.0	233.0	146.0	24.0	46.0	16.0	157.0
Ingenious	7.0	40.0	25.0	2.0	2.0	1.0	26.0
Inspiring	138.0	321.0	147.0	25.0	31.0	58.0	158.0
Jaw-dropping	4.0	36.0	10.0	NaN	NaN	NaN	3.0
Longwinded	1.0	7.0	NaN	NaN	NaN	NaN	NaN
OK	2.0	4.0	1.0	NaN	NaN	NaN	NaN
Obnoxious	NaN	2.0	NaN	NaN	NaN	NaN	2.0
Persuasive	7.0	27.0	22.0	3.0	5.0	1.0	18.0
Unconvincing	3.0	15.0	2.0	NaN	1.0	NaN	2.0
